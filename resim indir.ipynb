# %%
# !pip install bing_image_downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("kıyafet", limit=8, output_dir='images')
# Out:
# [%] Downloading Images to /content/images/kıyafet
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 8 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.welcomebaby.com.tr/Uploads/UrunResimleri/our-generation-kiyafetdream-come-true-pe-bf23.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.welcomebaby.com.tr/Uploads/UrunResimleri/buyuk/our-generation-kiyafetwish-come-true-bbc4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.isabelabbey.com.tr/Uploads/UrunResimleri/Our-Generation-KiyafetWish-Come-True-9652.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.isabelabbey.com.tr/Uploads/UrunResimleri/Our-Generation-KiyafetDream-Come-True-cbe2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.isabelabbey.com.tr/Uploads/UrunResimleri/buyuk/Our-Generation-KiyafetDream-Come-True-9c33.png
# [%] File Downloaded !
#
# ...
